# %% [markdown]
# ### С файлами их всегда много
# ### Упражнение на списки и функции
# Дана строчка sequence с последовательностью натуральных чисел, разделенных пробелом. Посчитайте:
# 1. Количество четных и нечетных чисел в этой строке
# 2. Если четных больше, то укажите номер позиции первого "лишнего" нечетного числа
# 3. Если нечетных больше, то укажите позицию первого "лишнего" четного числа
# 4. Как бонусный вариант оформите код в виде функции

# %%
sequence = '2 3 1 5 9 22 3 5'

# %% [markdown]
# Может пригодиться:

# %%
# получить список из строки
sequence.split(' ')
# Out:
# ['2', '3', '1', '5', '9', '22', '3', '5']

# %%
# перевод строки в целое число
int('2')

# %%
# проверка четности
22 % 2 == 0

# %%
new_list = sequence.split(' ')
even = 0
odd = 0
for num in new_list:
    if int(num) % 2 == 0:
        even += 1
    else:
        odd += 1

# %% [markdown]
# # Чтение файлов
# Рассматриваем задачу сквозной аналитики. Будем работать с этими файлами:
# - visit_log.csv
# - purchase_log.txt

# %% [markdown]
# ### Способ 1. Делаем все пошагово
# Опции при открытии файлов:
# - 'r' открыть для чтения. Файл при этом не меняется
# - 'w' открыть файл для записи. Файл при этом полностью чистится (!)
# - 'a' открыть файл для добавления. Файл не меняется, все записи добавляются в конец

# %%
# открываем файл для чтения (опция r)
f = open('visit_log.csv', 'r')

# %%
f
# Out:
# <_io.TextIOWrapper name='visit_log.csv' mode='r' encoding='cp1251'>

# %%
# прочитать одну строчку
f.readline()
# Out:
# 'user_id,source\n'

# %%
# прочитать еще одну
f.readline()
# Out:
# '6450655ae8,other\n'

# %%
# можно и так
next(f)
# Out:
# 'b4ea53e670,other\n'

# %%
# прочитать все содержимое файла в переменную content
content = f.readlines()

# %%
content[:5]
# Out:
# ['0e37347152,other\n',
#  '96064ae9e0,other\n',
#  'e1bd168161,context\n',
#  '71bcf169b4,other\n',
#  'e0aee73c5d,other\n']

# %%
# Так можно прочитать весь, файл. В переменной f будет объект, который будет выплевывать файл построчно
for line in f:
    print(line)
    
    break

# %% [markdown]
# Часто используется конструкция
# ```python
# another_line.strip().split(',')
# ```

# %%
another_line = f.readline()
another_line
# Out:
# ''

# %%
print('Перенос \nстроки')
# Out:
# Перенос
# строки

# %%
# удаляем перенос строки и лишние пробелы
another_line.strip()
# Out:
# ''

# %%
'333  6450655ae8,other  333'.strip(' 3')
# Out:
# '6450655ae8,other'

# %%
# разбиваем столбцы
another_line.strip().split(',')
# Out:
# ['']

# %%
another_line.split(',')
# Out:
# ['']

# %%
f.close()

# %%
# после закрытия не получится прочитать
f.readline()

# %%
# прочитать все строчки файла
f = open('visit_log.csv', 'r')

content = f.readlines()

f.close()

# %%
content[:5]

# %% [markdown]
# ### Упражнение
# Напишите функцию (или просто код), который возвращает список из первых N строк файла purchase_log.csv без записи всего содержимого файла в оперативную память.

# %%
f = open('purchase_log.txt', 'r')

# %%
content = f.readlines()
content[:5]
# Out:
# <_io.TextIOWrapper name='purchase_log.txt' mode='r' encoding='cp1251'>

# %%
# мой Вариант с записью всего файла (не так) ----Эта функция возвращает в оперативную память !!!!!!!!!!!!!
def n_strok(n):
    f = open('purchase_log.txt', 'r')
    content = f.readlines()
    print(content[:n])
    return

# %%
n_strok(5)
# Out:
# ['{"user_id": "user_id", "category": "category"}\n', '{"user_id": "1840e0b9d4", "category": "РџСЂРѕРґСѓРєС‚С‹"}\n', '{"user_id": "4e4f90fcfb", "category": "Р\xadР»РµРєС‚СЂРѕРЅРёРєР°"}\n', '{"user_id": "afea8d72fc", "category": "Р\xadР»РµРєС‚СЂРѕРЅРёРєР°"}\n', '{"user_id": "373a6055fe", "category": "Р‘С‹С‚РѕРІР°СЏ С‚РµС…РЅРёРєР°"}\n']

# %%
# Правильный вариант из лекции
f = open('purchase_log.txt', 'r')
for i in range(int(input('Input row number '))):
    print(f.readline().strip())
# Out:
# Input row number 3
# {"user_id": "user_id", "category": "category"}
# {"user_id": "1840e0b9d4", "category": "РџСЂРѕРґСѓРєС‚С‹"}
# {"user_id": "4e4f90fcfb", "category": "Р­Р»РµРєС‚СЂРѕРЅРёРєР°"}

# %%
# Еще один хороший пример
def get_row(f, n):
    list_n = []
    for line in f: # Можно использовать просто f вместо readline
        list_n.append(line.strip().split(','))
    return list_n

# %%
get_row(f,5)
# Out:
# [['{"user_id": "afea8d72fc"', ' "category": "Р\xadР»РµРєС‚СЂРѕРЅРёРєР°"}'],
#  ['{"user_id": "373a6055fe"', ' "category": "Р‘С‹С‚РѕРІР°СЏ С‚РµС…РЅРёРєР°"}'],
#  ['{"user_id": "9b2ab046f3"', ' "category": "Р\xadР»РµРєС‚СЂРѕРЅРёРєР°"}'],
#  ['{"user_id": "9f39d307c3"', ' "category": "Р\xadР»РµРєС‚СЂРѕРЅРёРєР°"}'],
#  ['{"user_id": "44edeffc91"', ' "category": "РџСЂРѕРґСѓРєС‚С‹"}'],
#  ['{"user_id": "704474fa2d"', ' "category": "РџСЂРѕРґСѓРєС‚С‹"}'],
#  ['{"user_id": "1de31be403"', ' "category": "Р‘С‹С‚РѕРІР°СЏ С‚РµС…РЅРёРєР°"}'],
#  ['{"user_id": "b71f36a5e4"', ' "category": "РџСЂРѕРґСѓРєС‚С‹"}'],
#  ['{"user_id": "79843a685a"', ' "category": "РџСЂРѕРґСѓРєС‚С‹"}'],
#  ['{"user_id": "ff68cee0d6"', ' "category": "Р‘С‹С‚РѕРІР°СЏ С‚РµС…РЅРёРєР°"}'],
#  ['{"user_id": "e8447c40e2"', ' "category": "Р”РѕСЃСѓРі"}'],
#  ['{"user_id": "98d290be27"', ' "category": "Р\xadР»РµРєС‚СЂРѕРЅРёРєР°"}'],
#  ['{"user_id": "fa0079a5a8"', ' "category": "Р”РѕСЃСѓРі"}'],
# ...

# %% [markdown]
# ### Зачем все так сложно?
# Начинаем запись в файл

# %%
f = open('results.csv', 'w')

# %%
f.write('Начинаю запись первой строки...\n')

# %%
f.write('Начинаю запись второй строки...\n')

# %% [markdown]
# Здесь кто-то еще хочет в него записать

# %%
my_friend_results = open('results.csv', 'w')

# %%
my_friend_results.write('Тут еще результаты есть')

# %%
# пишем свой результат
f.close()

# %%
# и наш результат перезатирается
my_friend_results.close()

# %% [markdown]
# ### Контекстный менеджер
# Как обезопасить себя от подобных накладок

# %%
with open('results.csv', 'w') as f:
    f.write('Начинаю запись первой строки...\n')
    f.write('Начинаю запись второй строки...\n')
    
    my_friend_results = open('results.csv', 'w')
    my_friend_results.write('Тут еще результаты есть')
    my_friend_results.close()

# %% [markdown]
# ### Упражнение
# Напишите функцию, которая фильтрует файл visit_log.csv по источнику context и пишет результат в visits_context.csv. Используйте функцию из второго упражнения для проверки результата.

# %%
i = 0
with open('visit_log.csv', 'r') as f:
    with open('visits_context.csv', 'w') as f2write:
        f2write.write(line) #Запись первого столбца (заголовка)
        for line in f:
            if 'context' in line:
                f2write.write(line)
#             i += 1
#             if i > 5:
                
# #             print(line)
#                 break

# %% [markdown]
# # Чтение списков и словарей из файла
# Смотрим что в файле purchase_log.txt. Похоже тут не строки, а словари

# %%
with open('purchase_log.txt') as f:
    print([next(f) for x in range(5)])
# Out:
# ['{"user_id": "user_id", "category": "category"}\n', '{"user_id": "1840e0b9d4", "category": "РџСЂРѕРґСѓРєС‚С‹"}\n', '{"user_id": "4e4f90fcfb", "category": "Р\xadР»РµРєС‚СЂРѕРЅРёРєР°"}\n', '{"user_id": "afea8d72fc", "category": "Р\xadР»РµРєС‚СЂРѕРЅРёРєР°"}\n', '{"user_id": "373a6055fe", "category": "Р‘С‹С‚РѕРІР°СЏ С‚РµС…РЅРёРєР°"}\n']

# %%
import json

# %%
# перевод строки в словарь
dict_in_string = '{"a": 1, "b": 2}'

type(json.loads(dict_in_string))
# Out:
# dict

# %%
json.loads(dict_in_string).values()
# Out:
# dict_values([1, 2])

# %%
# перевод строки в список
list_in_string = '[1, 2, 3]'

json.loads(list_in_string)[-1]
# Out:
# 3

# %%
# Для ДЗ необходимо использовать этот вариант
i = 0
with open('purchase_log.txt' , encoding= 'utf-8') as f:
    for line in f:
        line = line.strip()
        
        dict_ = json.loads(line)
        print(dict_, type(dict_))
        
        i += 1
        if i > 5:
            break
# Out:
# {'user_id': 'user_id', 'category': 'category'} <class 'dict'>
# {'user_id': '1840e0b9d4', 'category': 'Продукты'} <class 'dict'>
# {'user_id': '4e4f90fcfb', 'category': 'Электроника'} <class 'dict'>
# {'user_id': 'afea8d72fc', 'category': 'Электроника'} <class 'dict'>
# {'user_id': '373a6055fe', 'category': 'Бытовая техника'} <class 'dict'>
# {'user_id': '9b2ab046f3', 'category': 'Электроника'} <class 'dict'>

# %% [markdown]
# ### Упражнение
# 1. Посчитайте распределение количества покупок по категориям в столбце category
# 2. Составьте словарь, в котором для каждого user_id значением будет название категории

# %% [markdown]
# ### Из словаря в строку тоже можно

# %%
data = {'user_id': '1840e0b9d4', 'category': 'Продукты'}

# %%
json.dumps(data)

# %%
type(json.dumps(data))

# %% [markdown]
# # Модуль pickle
# Запись объекта сразу в файл как поток байтов

# %%
import pickle

# %%
data = {'user_id': '1840e0b9d4', 'category': 'Продукты'}

# %%
with open('data.pickle', 'wb') as f:
    pickle.dump(data, f)

# %%
# прочитать объект из такого файла

with open('data.pickle', 'rb') as f:
    dict_ = pickle.load(f)
    
dict_, dict_['user_id']
# Out:
# ({'user_id': '1840e0b9d4', 'category': 'Продукты'}, '1840e0b9d4')

# %% [markdown]
# ### Упражнение
# В файле payments_stat.pickle записана некая статистика платежей пользователей. Посчитайте среднее значение платежа.

# %% [markdown]
# # Каталог пакетов pip (Python Package Index)
# Варианты установки
# 1. С помощью Anaconda Navigator
# 2. В командной строке (Terminal на маке)
# ```bash
# pip install package_name
# ```
# 3. Скачать версию с github и установить вручную
# ```bash
# pip install .
# ```
#
# Пакеты устанавливаются в определенное окружение! Вам пригодится virtualenv

# %%
# !pip install pyyaml

# %%
import plotly

# %% [markdown]
# # Простой импорт

# %%
import sys
sys.path

# %%
# добавляем в список библиотек папку libs
sys.path.append('libs')
sys.path

# %%
from useful_codes import CATEGORIES

# %%
CATEGORIES

# %%
from useful_codes import word_count

# %%
# посмотреть документацию функции

# ?word_count

# %%
word_count('Посчитай количество слов в тексте')

# %% [markdown]
# # Домашнее задание
# 1. Переведите содержимое файла purchase_log.txt в словарь purchases вида:
# ```python
# {'1840e0b9d4': 'Продукты', ...}
# ```
#
# 2. Для каждого user_id в файле visit_log.csv добавьте третий столбец с категорией покупки (если покупка была).
#
# 3. Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были покупки с указанием категории.
#
# Учтите условия на данные:
# - содержимое purchase_log.txt помещается в оперативную память компьютера
# - содержимое visit_log.csv - нет; используйте только построчную обработку этого файла

# %%
# моя версия
purchase = {}
purchase_2 = {}
i = 0
import json
with open('purchase_log.txt', 'r', encoding="utf-8") as q:
    for line in q:
        line = line.strip()
        purchase = json.loads(line)
        purchase_2[purchase['user_id']] = purchase['category']
        i += 1
        if i > 10:
            break
    print(purchase_2)
# Out:
# {'user_id': 'category', '1840e0b9d4': 'Продукты', '4e4f90fcfb': 'Электроника', 'afea8d72fc': 'Электроника', '373a6055fe': 'Бытовая техника', '9b2ab046f3': 'Электроника', '9f39d307c3': 'Электроника', '44edeffc91': 'Продукты', '704474fa2d': 'Продукты', '1de31be403': 'Бытовая техника', 'b71f36a5e4': 'Продукты'}

# %%
# мой вариант Для каждого user_id в файле visit_log.csv добавьте третий столбец с категорией покупки (если покупка была)
peremennaya = []
with open('funnel.csv', 'w', encoding="utf-8") as visit_log_new:
        with open('visit_log.csv', 'r') as f:
            for i in f:
                i_line = f.readline().strip().split(',') #Убрал переносы и сделал список
                if purchases.get(i_line[0]): #методом .get ищем в словаре purchases из прошлого пункта по айди - (i_line[0]) ищем значение.
                    i_line.append(purchases[i_line[0]] + '\n')
#                     print(i_line)
#                     visit_log_new.write(i_line)   
                    peremennaya = ', '.join([str(elem) for elem in i_line]) #для записи argument must be str, not list
#                     peremennaya = peremennaya + '\n'
                    print(peremennaya)  
                    visit_log_new.write(peremennaya)
# Out:
# 4e4f90fcfb, context, Электроника
#
# afea8d72fc, other, Электроника
#
# 9b2ab046f3, other, Электроника
#
# 9f39d307c3, context, Электроника
#
# 44edeffc91, context, Продукты
#
# 1de31be403, other, Бытовая техника
#
# b71f36a5e4, other, Продукты
#
# ff68cee0d6, context, Бытовая техника
